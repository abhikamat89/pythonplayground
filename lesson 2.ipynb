# %%
# !pip install --upgrade gspread oauth2client
# Out:
# Requirement already satisfied: gspread in /usr/local/lib/python3.10/dist-packages (6.0.2)
# Collecting gspread
#   Downloading gspread-6.1.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.10/dist-packages (4.1.3)
# Requirement already satisfied: google-auth>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from gspread) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from gspread) (1.2.1)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.22.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.6.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.4.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (4.9)
# Requirement already satisfied: six>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread) (5.4.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2>=0.9.1->oauth2client) (3.1.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2024.7.4)
# Downloading gspread-6.1.2-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: gspread
#   Attempting uninstall: gspread
#     Found existing installation: gspread 6.0.2
#     Uninstalling gspread-6.0.2:
#       Successfully uninstalled gspread-6.0.2
# Successfully installed gspread-6.1.2

# %%
# !pip install gspread google-auth
# Out:
# Requirement already satisfied: gspread in /usr/local/lib/python3.10/dist-packages (6.1.2)
# Requirement already satisfied: google-auth in /usr/local/lib/python3.10/dist-packages (2.27.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from gspread) (1.2.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2024.7.4)

# %%
import gspread
from google.auth.transport.requests import Request
from google.oauth2.service_account import Credentials
import pandas as pd

# %%
# Path to your credentials file
credentials_file = '/content/intense-reactor-324805-7ce61613ca12.json'

# Define the scope for accessing Google Sheets and Google Drive
scope = ["https://spreadsheets.google.com/feeds", "https://www.googleapis.com/auth/drive"]

# Load the credentials from the JSON file
creds = Credentials.from_service_account_file(credentials_file, scopes=scope)

# Authorize the client
gc = gspread.authorize(creds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cb98e45952d6> in <cell line: 8>()
#       6
#       7 # Load the credentials from the JSON file
# ----> 8 creds = Credentials.from_service_account_file(credentials_file, scopes=scope)
#       9
#      10 # Authorize the client
#
# NameError: name 'Credentials' is not defined

# %%
# Open the Google Sheet by name or URL
sheet = gc.open_by_url('https://docs.google.com/spreadsheets/d/1NMtEtknTExjFNhjwtPx3PDUg1VWuda9BIuIIBVegfe4/edit?usp=sharing')

# Select a worksheet by index or title
worksheet = sheet.get_worksheet(2)

# Extract and print all the values
values = worksheet.get_all_values()
print(values)
# Out:
# [['level', 'pn', 'name', 'category', 'location', 'qty', 'uom'], ['0', '90-0001', 'finished good A', 'TLA', '', '', ''], ['1', '10-0002', 'assembly 1', 'Assy', '', '2', 'ea'], ['2', '10-0014', 'sub assembly 1', 'Part', '', '3', 'ea'], ['3', '10-0015', 'part 1', 'Part', '', '1', 'ea'], ['3', '10-0016', 'part 2', 'Part', '', '20', 'ea'], ['4', '10-0017', 'material 1', 'Part', '', '100', 'gram'], ['4', '10-0018', 'material 2', 'Part', '', '200', 'gram'], ['2', '10-0019', 'part 3', 'Part', '', '2', 'ea'], ['1', '10-0003', 'assembly 2', 'Assy', '', '1', 'ea'], ['1', '10-0004', 'assembly 3', 'Assy', '', '1', 'ea'], ['1', '10-0005', 'assembly 4', 'Assy', '', '1', 'ea'], ['1', '10-0006', 'assembly 5', 'Assy', '', '1', 'ea'], ['1', '10-0007', 'assembly 6', 'Assy', '', '1', 'ea'], ['2', '20-0020', 'motherboard', 'PCBA', '', '', 'ea'], ['3', '10-0021', 'cap1', 'Component', 'c1, c2, c3', '3', 'ea'], ['3', '10-0022', 'cap2', 'Component', 'c5', '1', 'ea'], ['3', '10-0023', 'res1', 'Component', 'r1', '1', 'ea'], ['3', '10-0024', 'ind1', 'Component', 'i1', '1', 'ea'], ['3', '10-0025', 'res2', 'Component', 'r2, r3, r4, r56, r57', '5', 'ea'], ['3', '10-0026', 'ind2', 'Component', 'i24, i27', '2', 'ea'], ['3', '10-0027', 'res5', 'Component', 'r34, r35', '2', 'ea'], ['3', '20-0028', 'pcb', 'PCB', '', '1', 'ea']]

# %%
data = worksheet.get_all_records()

# %%
print(data)
# Out:
# [{'level': 0, 'pn': '90-0001', 'name': 'finished good A', 'category': 'TLA', 'location': '', 'qty': '', 'uom': ''}, {'level': 1, 'pn': '10-0002', 'name': 'assembly 1', 'category': 'Assy', 'location': '', 'qty': 2, 'uom': 'ea'}, {'level': 2, 'pn': '10-0014', 'name': 'sub assembly 1', 'category': 'Part', 'location': '', 'qty': 3, 'uom': 'ea'}, {'level': 3, 'pn': '10-0015', 'name': 'part 1', 'category': 'Part', 'location': '', 'qty': 1, 'uom': 'ea'}, {'level': 3, 'pn': '10-0016', 'name': 'part 2', 'category': 'Part', 'location': '', 'qty': 20, 'uom': 'ea'}, {'level': 4, 'pn': '10-0017', 'name': 'material 1', 'category': 'Part', 'location': '', 'qty': 100, 'uom': 'gram'}, {'level': 4, 'pn': '10-0018', 'name': 'material 2', 'category': 'Part', 'location': '', 'qty': 200, 'uom': 'gram'}, {'level': 2, 'pn': '10-0019', 'name': 'part 3', 'category': 'Part', 'location': '', 'qty': 2, 'uom': 'ea'}, {'level': 1, 'pn': '10-0003', 'name': 'assembly 2', 'category': 'Assy', 'location': '', 'qty': 1, 'uom': 'ea'}, {'level': 1, 'pn': '10-0004', 'name': 'assembly 3', 'category': 'Assy', 'location': '', 'qty': 1, 'uom': 'ea'}, {'level': 1, 'pn': '10-0005', 'name': 'assembly 4', 'category': 'Assy', 'location': '', 'qty': 1, 'uom': 'ea'}, {'level': 1, 'pn': '10-0006', 'name': 'assembly 5', 'category': 'Assy', 'location': '', 'qty': 1, 'uom': 'ea'}, {'level': 1, 'pn': '10-0007', 'name': 'assembly 6', 'category': 'Assy', 'location': '', 'qty': 1, 'uom': 'ea'}, {'level': 2, 'pn': '20-0020', 'name': 'motherboard', 'category': 'PCBA', 'location': '', 'qty': '', 'uom': 'ea'}, {'level': 3, 'pn': '10-0021', 'name': 'cap1', 'category': 'Component', 'location': 'c1, c2, c3', 'qty': 3, 'uom': 'ea'}, {'level': 3, 'pn': '10-0022', 'name': 'cap2', 'category': 'Component', 'location': 'c5', 'qty': 1, 'uom': 'ea'}, {'level': 3, 'pn': '10-0023', 'name': 'res1', 'category': 'Component', 'location': 'r1', 'qty': 1, 'uom': 'ea'}, {'level': 3, 'pn': '10-0024', 'name': 'ind1', 'category': 'Component', 'location': 'i1', 'qty': 1, 'uom': 'ea'}, {'level': 3, 'pn': '10-0025', 'name': 'res2', 'category': 'Component', 'location': 'r2, r3, r4, r56, r57', 'qty': 5, 'uom': 'ea'}, {'level': 3, 'pn': '10-0026', 'name': 'ind2', 'category': 'Component', 'location': 'i24, i27', 'qty': 2, 'uom': 'ea'}, {'level': 3, 'pn': '10-0027', 'name': 'res5', 'category': 'Component', 'location': 'r34, r35', 'qty': 2, 'uom': 'ea'}, {'level': 3, 'pn': '20-0028', 'name': 'pcb', 'category': 'PCB', 'location': '', 'qty': 1, 'uom': 'ea'}]

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     level       pn             name   category              location  qty  \
# 0       0  90-0001  finished good A        TLA
# 1       1  10-0002       assembly 1       Assy                          2
# 2       2  10-0014   sub assembly 1       Part                          3
# 3       3  10-0015           part 1       Part                          1
# 4       3  10-0016           part 2       Part                         20
# 5       4  10-0017       material 1       Part                        100
# 6       4  10-0018       material 2       Part                        200
# 7       2  10-0019           part 3       Part                          2
# 8       1  10-0003       assembly 2       Assy                          1
# 9       1  10-0004       assembly 3       Assy                          1
# 10      1  10-0005       assembly 4       Assy                          1
# 11      1  10-0006       assembly 5       Assy                          1
# 12      1  10-0007       assembly 6       Assy                          1
# 13      2  20-0020      motherboard       PCBA
# 14      3  10-0021             cap1  Component            c1, c2, c3    3
# 15      3  10-0022             cap2  Component                    c5    1
# 16      3  10-0023             res1  Component                    r1    1
# 17      3  10-0024             ind1  Component                    i1    1
# 18      3  10-0025             res2  Component  r2, r3, r4, r56, r57    5
# 19      3  10-0026             ind2  Component              i24, i27    2
# 20      3  10-0027             res5  Component              r34, r35    2
# 21      3  20-0028              pcb        PCB                          1
#
#      uom
# 0
# 1     ea
# 2     ea
# 3     ea
# 4     ea
# 5   gram
# 6   gram
# 7     ea
# 8     ea
# 9     ea
# 10    ea
# 11    ea
# 12    ea
# 13    ea
# 14    ea
# 15    ea
# 16    ea
# 17    ea
# 18    ea
# 19    ea
# 20    ea
# 21    ea
