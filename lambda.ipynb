# %%
actor_lines = {'Michael': 12137,
 'Pam': 5375,
 'Dwight': 7529,
 'Angela': 1695,
 'Kelly': 956,
 'Jim': 6814,
 'Andy': 3968,
 'Kevin': 1708,
 'Phyllis': 1071,
 'Meredith': 645,
 'Oscar': 1490}

# %%
actor_lines.items()

def sort_by_key(item):
    return item[1]

sorted(actor_lines.items(), key=sort_by_key)
# Out:
# [('Meredith', 645),
#  ('Kelly', 956),
#  ('Phyllis', 1071),
#  ('Oscar', 1490),
#  ('Angela', 1695),
#  ('Kevin', 1708),
#  ('Andy', 3968),
#  ('Pam', 5375),
#  ('Jim', 6814),
#  ('Dwight', 7529),
#  ('Michael', 12137)]

# %%
sort_by_key({1:2})
# Out:
# 2
