# %%
   +------------------------+
   |   Import requests      |
   |  (import requests)     |
   +------------------------+
              |
              v
   +------------------------+
   | Define API URL         |
   | (url = "API endpoint") |
   +------------------------+
              |
              v
   +------------------------+
   |   Send GET Request     |
   | (response = requests.get(url)) |
   +------------------------+
              |
              v
   +------------------------+
   | Check Response Status  |
   | (if response.status_code == 200)  |
   +------------------------+
             / \
            /   \
           /Yes  \No
          /       \
         v         v
+----------------+  +-------------------------+
| Parse JSON     |  | Print Error Message     |
| (data = response.json())  | (print("Error fetching data:", status_code)) |
+----------------+  +-------------------------+
         |
         v
+----------------+
| Process Data |
| (e.g., print(data)) |
+----------------+
